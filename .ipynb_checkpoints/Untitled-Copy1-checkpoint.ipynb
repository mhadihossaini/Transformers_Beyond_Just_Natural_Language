# %%
import json
import re
import numpy as np
from collections import defaultdict
from transformers import BertModel, BertTokenizer
import torch
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from keybert import KeyBERT
from wordcloud import WordCloud

# Step 1: Load the Data
with open('papers.json', 'r', encoding="utf-8") as file:
    papers = json.load(file)

# Step 2: Text Preprocessing
def preprocess_text(text):
    if text is None:
        return ""
    text = text.lower()
    text = re.sub(r'\W+', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

for paper in papers:
    paper['abstractText'] = preprocess_text(paper['abstractText'])

# Step 3: Generate Embeddings
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

def get_embedding(text):
    inputs = tokenizer(text, return_tensors='pt', max_length=512, truncation=True, padding='max_length')
    outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).detach().numpy()

for paper in papers:
    paper['embedding'] = get_embedding(paper['abstractText'])

# Step 4: Compute Euclidean Distances
embeddings = [paper['embedding'] for paper in papers]
distances = euclidean_distances(embeddings)

# Step 5: Author Embeddings
author_embeddings = defaultdict(list)

for paper in papers:
    for author in paper['referenceAuthors']:
        author_embeddings[author].append(paper['embedding'])

for author in author_embeddings:
    author_embeddings[author] = np.mean(author_embeddings[author], axis=0)

# Step 6: Author Similarity
author_names = list(author_embeddings.keys())
author_vectors = list(author_embeddings.values())

author_distances = euclidean_distances(author_vectors)

# %%
import json
import re
import numpy as np
from collections import defaultdict
from transformers import DistilBertModel, DistilBertTokenizer
import torch
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from keybert import KeyBERT
from wordcloud import WordCloud

# Step 1: Load the Data
with open('papers.json', 'r', encode="utf-8") as file:
    papers = json.load(file)

# Step 2: Text Preprocessing
def preprocess_text(text):
    if text is None:
        return ""
    text = text.lower()
    text = re.sub(r'\W+', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

for paper in papers:
    paper['abstract'] = preprocess_text(paper.get('abstractText'))

# Step 3: Generate Embeddings using DistilBERT
model_name = 'distilbert-base-uncased'
tokenizer = DistilBertTokenizer.from_pretrained(model_name)
model = DistilBertModel.from_pretrained(model_name)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

def get_embedding(text):
    inputs = tokenizer(text, return_tensors='pt', max_length=512, truncation=True, padding='max_length')
    inputs = {key: value.to(device) for key, value in inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).cpu().numpy()

# Process embeddings in batches
batch_size = 16
all_embeddings = []
for i in range(0, len(papers), batch_size):
    batch = papers[i:i+batch_size]
    batch_embeddings = [get_embedding(paper['abstract']) for paper in batch]
    all_embeddings.extend(batch_embeddings)

for i, paper in enumerate(papers):
    paper['embedding'] = all_embeddings[i]

# Step 4: Compute Euclidean Distances
embeddings = np.vstack(all_embeddings)
distances = euclidean_distances(embeddings)

# Step 5: Author Embeddings
author_embeddings = defaultdict(list)

for paper in papers:
    for author in paper['authors']:
        author_embeddings[author].append(paper['embedding'])

for author in author_embeddings:
    author_embeddings[author] = np.mean(author_embeddings[author], axis=0)

# Step 6: Author Similarity
author_names = list(author_embeddings.keys())
author_vectors = np.vstack(list(author_embeddings.values()))

author_distances = euclidean_distances(author_vectors)

# Step 7: Find Closest Authors
author_recommendations = defaultdict(list)

for i, author in enumerate(author_names):
    distances = [(author_names[j], author_distances[i][j]) for j in range(len(author_names)) if author_names[j] != author]
    distances.sort(key=lambda x: x[1])
    co_authors = [coauthor for paper in papers for coauthor in paper['authors'] if author in paper['authors']]
    closest_authors = [name for name, dist in distances if name not in co_authors][:5]
    author_recommendations[author] = closest_authors

# Step 8: Dimensionality Reduction and Visualization
tsne = TSNE(n_components=2, random_state=42)
reduced_embeddings = tsne.fit_transform(author_vectors)

plt.figure(figsize=(10, 10))
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1])
for i, author in enumerate(author_names):
    plt.annotate(author, (reduced_embeddings[i, 0], reduced_embeddings[i, 1]))
plt.title('Authors in 2D space')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# Step 9: Clustering
kmeans = KMeans(n_clusters=8, random_state=42)
clusters = kmeans.fit_predict(author_vectors)

plt.figure(figsize=(10, 10))
for i in range(8):
    cluster_points = reduced_embeddings[clusters == i]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {i}')
plt.legend()
plt.title('Clusters of Authors')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# Step 10: Keyword Extraction
kw_model = KeyBERT(model_name)

cluster_texts = defaultdict(str)

for i, author in enumerate(author_names):
    cluster_texts[clusters[i]] += ' ' + ' '.join([paper['abstract'] for paper in papers if author in paper['authors']])

for cluster in cluster_texts:
    keywords = kw_model.extract_keywords(cluster_texts[cluster], keyphrase_ngram_range=(1, 2), stop_words='english', top_n=10)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join([kw for kw, _ in keywords]))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Cluster {cluster} Keywords')
    plt.show()
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# C:\Users\M-HADI\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\M-HADI\.cache\huggingface\hub\models--distilbert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 50
#      48 for i in range(0, len(papers), batch_size):
#      49     batch = papers[i:i+batch_size]
# ---> 50     batch_embeddings = [get_embedding(paper['abstract']) for paper in batch]
#      51     all_embeddings.extend(batch_embeddings)
#      53 for i, paper in enumerate(papers):
#
# Cell In[8], line 50, in <listcomp>(.0)
#      48 for i in range(0, len(papers), batch_size):
#      49     batch = papers[i:i+batch_size]
# ---> 50     batch_embeddings = [get_embedding(paper['abstract']) for paper in batch]
#      51     all_embeddings.extend(batch_embeddings)
#      53 for i, paper in enumerate(papers):
#
# Cell In[8], line 42, in get_embedding(text)
#      40 inputs = {key: value.to(device) for key, value in inputs.items()}
#      41 with torch.no_grad():
# ---> 42     outputs = model(**inputs)
#      43 return outputs.last_hidden_state.mean(dim=1).cpu().numpy()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:811, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     808     if attention_mask is None:
#     809         attention_mask = torch.ones(input_shape, device=device)  # (bs, seq_length)
# --> 811 return self.transformer(
#     812     x=embeddings,
#     813     attn_mask=attention_mask,
#     814     head_mask=head_mask,
#     815     output_attentions=output_attentions,
#     816     output_hidden_states=output_hidden_states,
#     817     return_dict=return_dict,
#     818 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:572, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     564     layer_outputs = self._gradient_checkpointing_func(
#     565         layer_module.__call__,
#     566         hidden_state,
#    (...)
#     569         output_attentions,
#     570     )
#     571 else:
# --> 572     layer_outputs = layer_module(
#     573         hidden_state,
#     574         attn_mask,
#     575         head_mask[i],
#     576         output_attentions,
#     577     )
#     579 hidden_state = layer_outputs[-1]
#     581 if output_attentions:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:498, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     488 """
#     489 Parameters:
#     490     x: torch.tensor(bs, seq_length, dim)
#    (...)
#     495     torch.tensor(bs, seq_length, dim) The output of the transformer block contextualization.
#     496 """
#     497 # Self-Attention
# --> 498 sa_output = self.attention(
#     499     query=x,
#     500     key=x,
#     501     value=x,
#     502     mask=attn_mask,
#     503     head_mask=head_mask,
#     504     output_attentions=output_attentions,
#     505 )
#     506 if output_attentions:
#     507     sa_output, sa_weights = sa_output  # (bs, seq_length, dim), (bs, n_heads, seq_length, seq_length)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:234, in MultiHeadSelfAttention.forward(self, query, key, value, mask, head_mask, output_attentions)
#     229 mask = (mask == 0).view(mask_reshp).expand_as(scores)  # (bs, n_heads, q_length, k_length)
#     230 scores = scores.masked_fill(
#     231     mask, torch.tensor(torch.finfo(scores.dtype).min)
#     232 )  # (bs, n_heads, q_length, k_length)
# --> 234 weights = nn.functional.softmax(scores, dim=-1)  # (bs, n_heads, q_length, k_length)
#     235 weights = self.dropout(weights)  # (bs, n_heads, q_length, k_length)
#     237 # Mask heads if we want to
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\functional.py:1858, in softmax(input, dim, _stacklevel, dtype)
#    1856     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1857 if dtype is None:
# -> 1858     ret = input.softmax(dim)
#    1859 else:
#    1860     ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:

# %%
import json
import re
import numpy as np
from collections import defaultdict
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from keybert import KeyBERT
from wordcloud import WordCloud

# Step 1: Load the Data
with open('papers.json', 'r', encoding="utf-8") as file:
    papers = json.load(file)

# Step 2: Text Preprocessing
def preprocess_text(text):
    if text is None:
        return ""
    text = text.lower()
    text = re.sub(r'\W+', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

for paper in papers:
    paper['abstract'] = preprocess_text(paper.get('abstractText'))

# Step 3: Generate Embeddings using SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')  # You can choose other models if needed

abstracts = [paper['abstract'] for paper in papers]
embeddings = model.encode(abstracts, batch_size=32, show_progress_bar=True)

for i, paper in enumerate(papers):
    paper['embedding'] = embeddings[i]

# Step 4: Compute Euclidean Distances
distances = euclidean_distances(embeddings)

# Step 5: Author Embeddings
author_embeddings = defaultdict(list)

for paper in papers:
    for author in paper['referenceAuthors']:
        author_embeddings[author].append(paper['embedding'])

for author in author_embeddings:
    author_embeddings[author] = np.mean(author_embeddings[author], axis=0)

# Step 6: Author Similarity
author_names = list(author_embeddings.keys())
author_vectors = np.vstack(list(author_embeddings.values()))

author_distances = euclidean_distances(author_vectors)
# Out:
# Batches:   0%|          | 0/236 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 46
#      44 for paper in papers:
#      45     for author in paper['referenceAuthors']:
# ---> 46         author_embeddings[author].append(paper['embedding'])
#      48 for author in author_embeddings:
#      49     author_embeddings[author] = np.mean(author_embeddings[author], axis=0)
#
# TypeError: unhashable type: 'dict'

# %%
# Step 7: Find Closest Authors
author_recommendations = defaultdict(list)

for i, author in enumerate(author_names):
    distances = [(author_names[j], author_distances[i][j]) for j in range(len(author_names)) if author_names[j] != author]
    distances.sort(key=lambda x: x[1])
    co_authors = [coauthor for paper in papers for coauthor in paper['authors'] if author in paper['authors']]
    closest_authors = [name for name, dist in distances if name not in co_authors][:5]
    author_recommendations[author] = closest_authors

# Step 8: Dimensionality Reduction and Visualization
tsne = TSNE(n_components=2, random_state=42)
reduced_embeddings = tsne.fit_transform(author_vectors)

plt.figure(figsize=(10, 10))
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1])
for i, author in enumerate(author_names):
    plt.annotate(author, (reduced_embeddings[i, 0], reduced_embeddings[i, 1]))
plt.title('Authors in 2D space')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# Step 9: Clustering
kmeans = KMeans(n_clusters=8, random_state=42)
clusters = kmeans.fit_predict(author_vectors)

plt.figure(figsize=(10, 10))
for i in range(8):
    cluster_points = reduced_embeddings[clusters == i]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {i}')
plt.legend()
plt.title('Clusters of Authors')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# Step 10: Keyword Extraction
kw_model = KeyBERT(model)

cluster_texts = defaultdict(str)

for i, author in enumerate(author_names):
    cluster_texts[clusters[i]] += ' ' + ' '.join([paper['abstract'] for paper in papers if author in paper['authors']])

for cluster in cluster_texts:
    keywords = kw_model.extract_keywords(cluster_texts[cluster], keyphrase_ngram_range=(1, 2), stop_words='english', top_n=10)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join([kw for kw, _ in keywords]))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Cluster {cluster} Keywords')
    plt.show()

# %%
import json
import re
import numpy as np
from collections import defaultdict
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from keybert import KeyBERT
from wordcloud import WordCloud

# Step 1: Load the Data
with open('papers.json', 'r', encoding="utf-8") as file:
    papers = json.load(file)

# Step 2: Text Preprocessing
def preprocess_text(text):
    if text is None:
        return ""
    text = text.lower()
    text = re.sub(r'\W+', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

for paper in papers:
    paper['abstract'] = preprocess_text(paper.get('abstractText'))
    paper['authors'] = [f"{author['person']['firstname']} {author['person']['lastname']}" for author in paper.get('referenceAuthors', [])]

# Step 3: Generate Embeddings using SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')  # You can choose other models if needed

abstracts = [paper['abstract'] for paper in papers]
embeddings = model.encode(abstracts, batch_size=32, show_progress_bar=True)

for i, paper in enumerate(papers):
    paper['embedding'] = embeddings[i]

# Step 4: Compute Euclidean Distances
distances = euclidean_distances(embeddings)

# Step 5: Author Embeddings
author_embeddings = defaultdict(list)

for paper in papers:
    for author in paper['authors']:
        author_embeddings[author].append(paper['embedding'])

for author in author_embeddings:
    author_embeddings[author] = np.mean(author_embeddings[author], axis=0)

# Step 6: Author Similarity
author_names = list(author_embeddings.keys())
author_vectors = np.vstack(list(author_embeddings.values()))

author_distances = euclidean_distances(author_vectors)

# Step 7: Find Closest Authors
author_recommendations = defaultdict(list)

for i, author in enumerate(author_names):
    distances = [(author_names[j], author_distances[i][j]) for j in range(len(author_names)) if author_names[j] != author]
    distances.sort(key=lambda x: x[1])
    co_authors = {coauthor for paper in papers for coauthor in paper['authors'] if author in paper['authors']}
    closest_authors = [name for name, dist in distances if name not in co_authors][:5]
    author_recommendations[author] = closest_authors

# Step 8: Dimensionality Reduction and Visualization
tsne = TSNE(n_components=2, random_state=42)
reduced_embeddings = tsne.fit_transform(author_vectors)

plt.figure(figsize=(10, 10))
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1])
for i, author in enumerate(author_names):
    plt.annotate(author, (reduced_embeddings[i, 0], reduced_embeddings[i, 1]))
plt.title('Authors in 2D space')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# Step 9: Clustering
kmeans = KMeans(n_clusters=8, random_state=42)
clusters = kmeans.fit_predict(author_vectors)

plt.figure(figsize=(10, 10))
for i in range(8):
    cluster_points = reduced_embeddings[clusters == i]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {i}')
plt.legend()
plt.title('Clusters of Authors')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# Step 10: Keyword Extraction
kw_model = KeyBERT(model)

cluster_texts = defaultdict(str)

for i, author in enumerate(author_names):
    cluster_texts[clusters[i]] += ' ' + ' '.join([paper['abstract'] for paper in papers if author in paper['authors']])

for cluster in cluster_texts:
    keywords = kw_model.extract_keywords(cluster_texts[cluster], keyphrase_ngram_range=(1, 2), stop_words='english', top_n=10)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join([kw for kw, _ in keywords]))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Cluster {cluster} Keywords')
    plt.show()
# Out:
# Batches:   0%|          | 0/236 [00:00<?, ?it/s]
